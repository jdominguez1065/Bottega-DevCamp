# %%
import math

# Ejercicio 1
lista = ['manzanas', 'platanos', 'peras', 'limones'] # List

tupla = ('Python', 'Fortran', 'Matlab', 'Javascript') # Tuple

flotante = float(3.141592653589793) # Float

entero = 27 # Integer

decimal = 53.95 # Decimal

diccionario = {
    'nombre': 'Jorge',
    'apellido': 'Dominguez'
} # Dictionary


# Ejercicio 2
print('Ejercicio 2')
redondeo = math.ceil(flotante)
print(f'    El número flotante redondeado hacia arriba es {redondeo}.')
print('''
      ''')


# Ejercicio 3
print('Ejercicio 3')
square_root = math.sqrt(flotante)
print(f'    La raiz cuadrada del número flotante es {square_root}.')
print('''
      ''')


# Ejercicio 4
print('Ejercicio 4')
primer_elemento = diccionario['nombre']
print(f'    El primer elemento del diccionario es {primer_elemento}')
print('''
      ''')


# Ejercicio 5
print('Ejercicio 5')
segundo_elemento = tupla[1]
print(f'    El segundo elemento de la tupla es {segundo_elemento}')
print('''
      ''')


# Ejercicio 6
print('Ejercicio 6')
lista.append('sandias')
print('    La lista con el elemento nuevo añadido al final es:')
print(lista)
print('''
      ''')


# Ejercicio 7
print('Ejercicio 7')
lista[0] = 'mandarinas'
print('    La lista con el primer elemento cambiado es:')
print(lista)
print('''
      ''')


# Ejercicio 8
print('Ejercicio 8')
print('    La lista ordenada alfabéticamente es:')
lista.sort()
print(lista)
print('''
      ''')


# Ejercicio 9
print('Ejercicio 9')
tupla = ('Python', 'Fortran', 'Matlab', 'Javascript', 'Ruby')
print('    La nueva tupla es:')
print(tupla)
# Out:
# Ejercicio 2
#     El número flotante redondeado hacia arriba es 4.
#
#
# Ejercicio 3
#     La raiz cuadrada del número flotante es 1.7724538509055159.
#
#
# Ejercicio 4
#     El primer elemento del diccionario es Jorge
#
#
# Ejercicio 5
#     El segundo elemento de la tupla es Fortran
#
#
# Ejercicio 6
#     La lista con el elemento nuevo añadido al final es:
# ['manzanas', 'platanos', 'peras', 'limones', 'sandias']
#
#
# Ejercicio 7
#     La lista con el primer elemento cambiado es:
# ['mandarinas', 'platanos', 'peras', 'limones', 'sandias']
#
#
# Ejercicio 8
#     La lista ordenada alfabéticamente es:
# ['limones', 'mandarinas', 'peras', 'platanos', 'sandias']
#
#
# Ejercicio 9
#     La nueva tupla es:
# ('Python', 'Fortran', 'Matlab', 'Javascript', 'Ruby')
